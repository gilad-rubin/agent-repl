# %% [markdown]
# # Demo Notebook
# This notebook demonstrates the v1 architecture.

# %%
import sys
print(f"Python {sys.version}") # test
 # saved
 # test-save
# test

 # saved
# Out:
# Python 3.12.9 (main, Mar 17 2025, 21:36:21) [Clang 20.1.0 ]

# %%
# Math example
result = sum(range(1, 101))
print(f"Sum of 1..100 = {result}")
# Out:
# Sum of 1..100 = 5050

# %%
# List comprehension
squares = [x**2 for x in range(10)]
print(squares)

# %%
print("Hello from the daemon!")
# Out:
# Hello from the daemon!

# %%
print("This was executed via CLI — if you see it live, WebSocket push is working!")
# Out:
# This was executed via CLI — if you see it live, WebSocket push is working!

# %%
print("Live sync test — executed from CLI")
# Out:
# Live sync test — executed from CLI

# %%
a=7

# %%
a
# Out:
# 7

# %%
import time
for i in range(5):
    print(f"step {i}")
    time.sleep(1)
print("done")
# Out:
# step 0
# step 1
# step 2
# step 3
# step 4
# done
